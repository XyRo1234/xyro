# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# - 한셀안의 인쇄동작을 모두 수행
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# - matplotlib 초기 설정(한글 폰트 설정)
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)
mpl.rc('font',size=16) # 전체 폰트크기 지정

# %% [markdown]
# ## [0]  suwon_census2.csv 파일 확인하기
# 2022년도 1월의 수원시 연령별 인구조사 데이터이다. 다음 코드를 실행하여 확인하라

# %%
df = pd.read_csv('suwon_census2.csv')
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Columns: 105 entries, 도 to 2022년01월_계_100세 이상
# dtypes: int64(101), object(4)
# memory usage: 36.2+ KB
#      도    시    구    동  2022년01월_계_0세  2022년01월_계_1세  2022년01월_계_2세  \
# 0  경기도  수원시  장안구  파장동             64             83             97
# 1  경기도  수원시  장안구  율천동            215            214            238
#
#    2022년01월_계_3세  2022년01월_계_4세  2022년01월_계_5세  ...  2022년01월_계_91세  \
# 0            107            107            146  ...              22
# 1            238            238            277  ...              25
#
#    2022년01월_계_92세  2022년01월_계_93세  2022년01월_계_94세  2022년01월_계_95세  \
# 0              28              16              10               3
# 1              28              12              18              10
#
#    2022년01월_계_96세  2022년01월_계_97세  2022년01월_계_98세  2022년01월_계_99세  \
# 0               4               4               3               6
# 1               7               5               3               4
#
#    2022년01월_계_100세 이상
# 0                   2
# 1                   5
#
# [2 rows x 105 columns]

# %% [markdown]
# ## [1] 컬럼명 편집
# ### 컬럼명을 년도와 월을 제거하여 나이로만 편집하라
# - rename()을 이용하며 split('_')로 구분하여 마지막 단어인 나이만 선택한다
# - 반드시 원본이 수정되도록 inplace 키워드를 이용한다
# - 다음 그림을 참조하여 편집한 결과를 인쇄하라(인쇄결과는 일부임)
#
# ![image-3.png](attachment:image-3.png)

# %%
# [1] 코드 작성
df.rename(columns=lambda x : x.split('_')[-1], inplace=True)
df
# Out:
#       도    시    구     동   0세   1세   2세   3세   4세   5세  ...  91세  92세  93세  \
# 0   경기도  수원시  장안구   파장동   64   83   97  107  107  146  ...   22   28   16
# 1   경기도  수원시  장안구   율천동  215  214  238  238  238  277  ...   25   28   12
# 2   경기도  수원시  장안구  정자1동   95  141  159  168  219  239  ...   22   24   20
# 3   경기도  수원시  장안구  정자2동  181  222  239  267  303  348  ...   19   30   14
# 4   경기도  수원시  장안구  정자3동  134  168  206  234  253  312  ...   26   21   14
# 5   경기도  수원시  장안구   영화동   54   65   59   80   67   75  ...   25   14   12
# 6   경기도  수원시  장안구   송죽동   78   82   85   96   97   98  ...   24   16   12
# 7   경기도  수원시  장안구  조원1동   62   93  100  113  125  133  ...   36   32   26
# 8   경기도  수원시  장안구  조원2동   80   88  100   93  125  140  ...   29   21   18
# 9   경기도  수원시  장안구   연무동   41   44   53   61   65   70  ...   17   28   17
# 10  경기도  수원시  권선구  세류1동   77   72   89   75   97   91  ...    5   10    8
# 11  경기도  수원시  권선구  세류2동   76   93   95  109  101  111  ...   15   24    6
# 12  경기도  수원시  권선구  세류3동   72   71   70   70   75   87  ...   13   21   10
# 13  경기도  수원시  권선구    평동  231  268  291  276  289  336  ...   31   30   20
# 14  경기도  수원시  권선구   서둔동  175  169  184  196  223  244  ...   22   19   17
# 15  경기도  수원시  권선구   구운동   82  110   98  132  118  136  ...   33    9   12
# 16  경기도  수원시  권선구   금곡동  267  304  298  384  425  484  ...   36   28   11
# 17  경기도  수원시  권선구  호매실동  425  473  568  582  642  744  ...   13   14   15
# 18  경기도  수원시  권선구  권선1동  104  104   99   98  126  112  ...   15   14    9
# 19  경기도  수원시  권선구  권선2동  305  375  380  459  505  584  ...   21   23   14
# 20  경기도  수원시  권선구   곡선동  167  179  202  187  216  241  ...   18   14   14
# 21  경기도  수원시  권선구   입북동   90  107  123  124  154  155  ...    8    9    6
# 22  경기도  수원시  팔달구   매교동   15   29   12   22   29   34  ...    7    2    2
# 23  경기도  수원시  팔달구   매산동   46   48   42   40   36   42  ...   15    6    8
# 24  경기도  수원시  팔달구   고등동  139  160  217  222  209  172  ...   13    8    8
# 25  경기도  수원시  팔달구  화서1동  107  100  108  111  127  157  ...   11   13   19
# 26  경기도  수원시  팔달구  화서2동  168  151  143  171  156  179  ...   17    9    9
# 27  경기도  수원시  팔달구    지동   16   22   33   31   36   43  ...   13   16    8
# 28  경기도  수원시  팔달구  우만1동   51   70   69   90   59   98  ...   13    9    7
# 29  경기도  수원시  팔달구  우만2동   75   75   70   98  107  111  ...    9   12   11
# 30  경기도  수원시  팔달구   인계동  154  159  157  167  193  226  ...   22   21   12
# 31  경기도  수원시  팔달구   행궁동   21   27   32   29   25   34  ...   17    9   10
# 32  경기도  수원시  영통구  매탄1동   62   71   94  101   92  112  ...   13    8    9
# 33  경기도  수원시  영통구  매탄2동   58   53   62   58   67   89  ...   15   10    5
# 34  경기도  수원시  영통구  매탄3동  139  153  220  212  223  261  ...   16   12   12
# 35  경기도  수원시  영통구  매탄4동  108   89  104  125  105  121  ...   16    9    9
# 36  경기도  수원시  영통구   원천동  261  278  288  337  360  411  ...   21   20   14
# 37  경기도  수원시  영통구  영통1동  254  243  255  262  283  316  ...   19   12    9
# 38  경기도  수원시  영통구  영통2동  312  278  262  206  230  228  ...   14    5   10
# 39  경기도  수원시  영통구  영통3동  149  157  197  179  217  243  ...   19   14   10
# 40  경기도  수원시  영통구  망포1동  195  239  290  301  328  366  ...   13   14   12
# 41  경기도  수원시  영통구  망포2동  249  283  306  382  402  469  ...    6   12    1
# 42  경기도  수원시  영통구  광교1동  326  321  358  423  493  539  ...   18   12   11
# 43  경기도  수원시  영통구  광교2동  260  319  288  305  282  330  ...   15    7   14
#
#     94세  95세  96세  97세  98세  99세  100세 이상
# 0    10    3    4    4    3    6        2
# 1    18   10    7    5    3    4        5
# 2    17    5    4    3    5    1        4
# 3    17   11    5    5    5    6        6
# 4    11    7    1    3    4    0        2
# 5    11    6   11    3    4    2        3
# 6     3    7    3    3    0    0        5
# 7    19   12    7    6    1    4        2
# 8     5   13    6    2    3    6        4
# 9    18   13    6    4    6    2        4
# 10    4    5    1    4    1    2        1
# 11    7    6    7    9    5    5        6
# 12    9    7    4    0    1    0        3
# 13   14    9   13    6    4    2        9
# 14   10    8    9   10    2    1        5
# 15   13    3    4    3    0    2        3
# 16   21    5    4    4    2    1        4
# 17   11    7   10    1    0    2        3
# 18    5    6    3    3    0    0        2
# 19    4    6    8    5    1    3        8
# 20   14    4    3    0    2    5        3
# 21    6    3    2    3    0    0        2
# 22    3    0    1    0    2    0        2
# 23    7    4    2    2    0    1        3
# 24    2    5    4    1    4    1        2
# 25   10    1    7    1    0    4        4
# 26    7    4    5    2    2    3        4
# 27    4    3    3    0    1    1        2
# 28   10    5    6    5    3    1        4
# 29    6    4    1    2    1    2        0
# 30    8    8    7    4    4    2        5
# 31    7    9    0    4    1    0        1
# 32    5    0    6    3    2    1        1
# 33    5    8    4    1    1    0        2
# 34    6    3    7    0    1    1        3
# 35    7    1    5    5    3    0        2
# 36   14    9    1    2    2    0        2
# 37    6   10    1    4    1    2        3
# 38    1    0    0    3    0    2        3
# 39    7    3    3    3    3    3        1
# 40    6    4    5    2    0    0        4
# 41    4    1    1    2    0    0        3
# 42    7    4    4    2    5    2        3
# 43    9    2    9    5    1    1        4
#
# [44 rows x 105 columns]

# %% [markdown]
# ## [2] index 편집 1
# ### 2-1. df에서 '구'와 '동'컬럼을 multiIndex화하여 ndf에 대입하라(아래 그림 참고)
# ![image-17.png](attachment:image-17.png)

# %%
# [2-1] 코드 작성
ndf = df.set_index(['구','동'])
ndf
# Out:
#             도    시   0세   1세   2세   3세   4세   5세   6세   7세  ...  91세  92세  \
# 구   동                                                       ...
# 장안구 파장동   경기도  수원시   64   83   97  107  107  146  130  144  ...   22   28
#     율천동   경기도  수원시  215  214  238  238  238  277  335  349  ...   25   28
#     정자1동  경기도  수원시   95  141  159  168  219  239  292  297  ...   22   24
#     정자2동  경기도  수원시  181  222  239  267  303  348  394  365  ...   19   30
#     정자3동  경기도  수원시  134  168  206  234  253  312  365  412  ...   26   21
#     영화동   경기도  수원시   54   65   59   80   67   75   92   84  ...   25   14
#     송죽동   경기도  수원시   78   82   85   96   97   98  122  126  ...   24   16
#     조원1동  경기도  수원시   62   93  100  113  125  133  177  164  ...   36   32
#     조원2동  경기도  수원시   80   88  100   93  125  140  154  156  ...   29   21
#     연무동   경기도  수원시   41   44   53   61   65   70   67   71  ...   17   28
# 권선구 세류1동  경기도  수원시   77   72   89   75   97   91   80   78  ...    5   10
#     세류2동  경기도  수원시   76   93   95  109  101  111  103  120  ...   15   24
#     세류3동  경기도  수원시   72   71   70   70   75   87   87   91  ...   13   21
#     평동    경기도  수원시  231  268  291  276  289  336  317  291  ...   31   30
#     서둔동   경기도  수원시  175  169  184  196  223  244  245  253  ...   22   19
#     구운동   경기도  수원시   82  110   98  132  118  136  146  136  ...   33    9
#     금곡동   경기도  수원시  267  304  298  384  425  484  584  550  ...   36   28
#     호매실동  경기도  수원시  425  473  568  582  642  744  856  745  ...   13   14
#     권선1동  경기도  수원시  104  104   99   98  126  112  125  124  ...   15   14
#     권선2동  경기도  수원시  305  375  380  459  505  584  648  604  ...   21   23
#     곡선동   경기도  수원시  167  179  202  187  216  241  224  240  ...   18   14
#     입북동   경기도  수원시   90  107  123  124  154  155  192  194  ...    8    9
# 팔달구 매교동   경기도  수원시   15   29   12   22   29   34   18   24  ...    7    2
#     매산동   경기도  수원시   46   48   42   40   36   42   42   33  ...   15    6
#     고등동   경기도  수원시  139  160  217  222  209  172  178  132  ...   13    8
#     화서1동  경기도  수원시  107  100  108  111  127  157  147  143  ...   11   13
#     화서2동  경기도  수원시  168  151  143  171  156  179  208  197  ...   17    9
#     지동    경기도  수원시   16   22   33   31   36   43   53   45  ...   13   16
#     우만1동  경기도  수원시   51   70   69   90   59   98   82   86  ...   13    9
#     우만2동  경기도  수원시   75   75   70   98  107  111  137  115  ...    9   12
#     인계동   경기도  수원시  154  159  157  167  193  226  199  235  ...   22   21
#     행궁동   경기도  수원시   21   27   32   29   25   34   13   26  ...   17    9
# 영통구 매탄1동  경기도  수원시   62   71   94  101   92  112  109  114  ...   13    8
#     매탄2동  경기도  수원시   58   53   62   58   67   89  103   96  ...   15   10
#     매탄3동  경기도  수원시  139  153  220  212  223  261  308  337  ...   16   12
#     매탄4동  경기도  수원시  108   89  104  125  105  121  137  121  ...   16    9
#     원천동   경기도  수원시  261  278  288  337  360  411  519  492  ...   21   20
#     영통1동  경기도  수원시  254  243  255  262  283  316  382  398  ...   19   12
#     영통2동  경기도  수원시  312  278  262  206  230  228  243  202  ...   14    5
#     영통3동  경기도  수원시  149  157  197  179  217  243  289  281  ...   19   14
#     망포1동  경기도  수원시  195  239  290  301  328  366  413  366  ...   13   14
#     망포2동  경기도  수원시  249  283  306  382  402  469  543  492  ...    6   12
#     광교1동  경기도  수원시  326  321  358  423  493  539  680  684  ...   18   12
#     광교2동  경기도  수원시  260  319  288  305  282  330  370  358  ...   15    7
#
#           93세  94세  95세  96세  97세  98세  99세  100세 이상
# 구   동
# 장안구 파장동    16   10    3    4    4    3    6        2
#     율천동    12   18   10    7    5    3    4        5
#     정자1동   20   17    5    4    3    5    1        4
#     정자2동   14   17   11    5    5    5    6        6
#     정자3동   14   11    7    1    3    4    0        2
#     영화동    12   11    6   11    3    4    2        3
#     송죽동    12    3    7    3    3    0    0        5
#     조원1동   26   19   12    7    6    1    4        2
#     조원2동   18    5   13    6    2    3    6        4
#     연무동    17   18   13    6    4    6    2        4
# 권선구 세류1동    8    4    5    1    4    1    2        1
#     세류2동    6    7    6    7    9    5    5        6
#     세류3동   10    9    7    4    0    1    0        3
#     평동     20   14    9   13    6    4    2        9
#     서둔동    17   10    8    9   10    2    1        5
#     구운동    12   13    3    4    3    0    2        3
#     금곡동    11   21    5    4    4    2    1        4
#     호매실동   15   11    7   10    1    0    2        3
#     권선1동    9    5    6    3    3    0    0        2
#     권선2동   14    4    6    8    5    1    3        8
#     곡선동    14   14    4    3    0    2    5        3
#     입북동     6    6    3    2    3    0    0        2
# 팔달구 매교동     2    3    0    1    0    2    0        2
#     매산동     8    7    4    2    2    0    1        3
#     고등동     8    2    5    4    1    4    1        2
#     화서1동   19   10    1    7    1    0    4        4
#     화서2동    9    7    4    5    2    2    3        4
#     지동      8    4    3    3    0    1    1        2
#     우만1동    7   10    5    6    5    3    1        4
#     우만2동   11    6    4    1    2    1    2        0
#     인계동    12    8    8    7    4    4    2        5
#     행궁동    10    7    9    0    4    1    0        1
# 영통구 매탄1동    9    5    0    6    3    2    1        1
#     매탄2동    5    5    8    4    1    1    0        2
#     매탄3동   12    6    3    7    0    1    1        3
#     매탄4동    9    7    1    5    5    3    0        2
#     원천동    14   14    9    1    2    2    0        2
#     영통1동    9    6   10    1    4    1    2        3
#     영통2동   10    1    0    0    3    0    2        3
#     영통3동   10    7    3    3    3    3    3        1
#     망포1동   12    6    4    5    2    0    0        4
#     망포2동    1    4    1    1    2    0    0        3
#     광교1동   11    7    4    4    2    5    2        3
#     광교2동   14    9    2    9    5    1    1        4
#
# [44 rows x 103 columns]

# %% [markdown]
# ### 2-2. 완성한 ndf를 이용하여 '장안구'를 인덱싱하여 인쇄하라
# - (참고) 멀티인덱스에서 0 level('구')을 선택하면 장안구 1 level의 모든 동이 추출된다
# - 아래 그림은 '장안구'를 인덱싱한 결과 일부이다
# ![image-18.png](attachment:image-18.png)

# %%
# [2-2] 코드 작성
ndf.loc['장안구']
# Out:
#         도    시   0세   1세   2세   3세   4세   5세   6세   7세  ...  91세  92세  93세  \
# 동                                                       ...
# 파장동   경기도  수원시   64   83   97  107  107  146  130  144  ...   22   28   16
# 율천동   경기도  수원시  215  214  238  238  238  277  335  349  ...   25   28   12
# 정자1동  경기도  수원시   95  141  159  168  219  239  292  297  ...   22   24   20
# 정자2동  경기도  수원시  181  222  239  267  303  348  394  365  ...   19   30   14
# 정자3동  경기도  수원시  134  168  206  234  253  312  365  412  ...   26   21   14
# 영화동   경기도  수원시   54   65   59   80   67   75   92   84  ...   25   14   12
# 송죽동   경기도  수원시   78   82   85   96   97   98  122  126  ...   24   16   12
# 조원1동  경기도  수원시   62   93  100  113  125  133  177  164  ...   36   32   26
# 조원2동  경기도  수원시   80   88  100   93  125  140  154  156  ...   29   21   18
# 연무동   경기도  수원시   41   44   53   61   65   70   67   71  ...   17   28   17
#
#       94세  95세  96세  97세  98세  99세  100세 이상
# 동
# 파장동    10    3    4    4    3    6        2
# 율천동    18   10    7    5    3    4        5
# 정자1동   17    5    4    3    5    1        4
# 정자2동   17   11    5    5    5    6        6
# 정자3동   11    7    1    3    4    0        2
# 영화동    11    6   11    3    4    2        3
# 송죽동     3    7    3    3    0    0        5
# 조원1동   19   12    7    6    1    4        2
# 조원2동    5   13    6    2    3    6        4
# 연무동    18   13    6    4    6    2        4
#
# [10 rows x 103 columns]

# %% [markdown]
# ## [3] index 편집 2
# ### 다음조건에 따라 순서대로 처리하여 ndf에 대입하여 인쇄하라
# 1. df에서 '구' 컬럼을 index화하고 '장안구' 데이터만 추출한다
# 2. 추출한 데이터프레임에서 index를 0부터 일련번호로 초기화하여 인쇄하라
# - (참고) index의 label은 중복이 가능하므로 중복된 '장안구' label이 모두 인덱싱 대상이 된다
# - 다음 그림은 ndf의 인쇄 결과 일부이다
# ![image-9.png](attachment:image-9.png) ![image-10.png](attachment:image-10.png)

# %%
# [3] 코드 작성
ndf = df.set_index('구').loc['장안구'].reset_index(drop=True)
ndf
# Out:
#      도    시     동   0세   1세   2세   3세   4세   5세   6세  ...  91세  92세  93세  94세  \
# 0  경기도  수원시   파장동   64   83   97  107  107  146  130  ...   22   28   16   10
# 1  경기도  수원시   율천동  215  214  238  238  238  277  335  ...   25   28   12   18
# 2  경기도  수원시  정자1동   95  141  159  168  219  239  292  ...   22   24   20   17
# 3  경기도  수원시  정자2동  181  222  239  267  303  348  394  ...   19   30   14   17
# 4  경기도  수원시  정자3동  134  168  206  234  253  312  365  ...   26   21   14   11
# 5  경기도  수원시   영화동   54   65   59   80   67   75   92  ...   25   14   12   11
# 6  경기도  수원시   송죽동   78   82   85   96   97   98  122  ...   24   16   12    3
# 7  경기도  수원시  조원1동   62   93  100  113  125  133  177  ...   36   32   26   19
# 8  경기도  수원시  조원2동   80   88  100   93  125  140  154  ...   29   21   18    5
# 9  경기도  수원시   연무동   41   44   53   61   65   70   67  ...   17   28   17   18
#
#    95세  96세  97세  98세  99세  100세 이상
# 0    3    4    4    3    6        2
# 1   10    7    5    3    4        5
# 2    5    4    3    5    1        4
# 3   11    5    5    5    6        6
# 4    7    1    3    4    0        2
# 5    6   11    3    4    2        3
# 6    7    3    3    0    0        5
# 7   12    7    6    1    4        2
# 8   13    6    2    3    6        4
# 9   13    6    4    6    2        4
#
# [10 rows x 104 columns]

# %% [markdown]
# ## [4] 정렬
# ### df에서 '구'와 '동' 컬럼을 기준으로 오름차순 정렬하여 인쇄하라
# - 다음 그림은 정렬한 결과의 일부이다
# ![image-2.png](attachment:image-2.png)

# %%
# [4] 코드 작성
df.sort_values(['구','동'])
# Out:
#       도    시    구     동   0세   1세   2세   3세   4세   5세  ...  91세  92세  93세  \
# 20  경기도  수원시  권선구   곡선동  167  179  202  187  216  241  ...   18   14   14
# 15  경기도  수원시  권선구   구운동   82  110   98  132  118  136  ...   33    9   12
# 18  경기도  수원시  권선구  권선1동  104  104   99   98  126  112  ...   15   14    9
# 19  경기도  수원시  권선구  권선2동  305  375  380  459  505  584  ...   21   23   14
# 16  경기도  수원시  권선구   금곡동  267  304  298  384  425  484  ...   36   28   11
# 14  경기도  수원시  권선구   서둔동  175  169  184  196  223  244  ...   22   19   17
# 10  경기도  수원시  권선구  세류1동   77   72   89   75   97   91  ...    5   10    8
# 11  경기도  수원시  권선구  세류2동   76   93   95  109  101  111  ...   15   24    6
# 12  경기도  수원시  권선구  세류3동   72   71   70   70   75   87  ...   13   21   10
# 21  경기도  수원시  권선구   입북동   90  107  123  124  154  155  ...    8    9    6
# 13  경기도  수원시  권선구    평동  231  268  291  276  289  336  ...   31   30   20
# 17  경기도  수원시  권선구  호매실동  425  473  568  582  642  744  ...   13   14   15
# 42  경기도  수원시  영통구  광교1동  326  321  358  423  493  539  ...   18   12   11
# 43  경기도  수원시  영통구  광교2동  260  319  288  305  282  330  ...   15    7   14
# 40  경기도  수원시  영통구  망포1동  195  239  290  301  328  366  ...   13   14   12
# 41  경기도  수원시  영통구  망포2동  249  283  306  382  402  469  ...    6   12    1
# 32  경기도  수원시  영통구  매탄1동   62   71   94  101   92  112  ...   13    8    9
# 33  경기도  수원시  영통구  매탄2동   58   53   62   58   67   89  ...   15   10    5
# 34  경기도  수원시  영통구  매탄3동  139  153  220  212  223  261  ...   16   12   12
# 35  경기도  수원시  영통구  매탄4동  108   89  104  125  105  121  ...   16    9    9
# 37  경기도  수원시  영통구  영통1동  254  243  255  262  283  316  ...   19   12    9
# 38  경기도  수원시  영통구  영통2동  312  278  262  206  230  228  ...   14    5   10
# 39  경기도  수원시  영통구  영통3동  149  157  197  179  217  243  ...   19   14   10
# 36  경기도  수원시  영통구   원천동  261  278  288  337  360  411  ...   21   20   14
# 6   경기도  수원시  장안구   송죽동   78   82   85   96   97   98  ...   24   16   12
# 9   경기도  수원시  장안구   연무동   41   44   53   61   65   70  ...   17   28   17
# 5   경기도  수원시  장안구   영화동   54   65   59   80   67   75  ...   25   14   12
# 1   경기도  수원시  장안구   율천동  215  214  238  238  238  277  ...   25   28   12
# 2   경기도  수원시  장안구  정자1동   95  141  159  168  219  239  ...   22   24   20
# 3   경기도  수원시  장안구  정자2동  181  222  239  267  303  348  ...   19   30   14
# 4   경기도  수원시  장안구  정자3동  134  168  206  234  253  312  ...   26   21   14
# 7   경기도  수원시  장안구  조원1동   62   93  100  113  125  133  ...   36   32   26
# 8   경기도  수원시  장안구  조원2동   80   88  100   93  125  140  ...   29   21   18
# 0   경기도  수원시  장안구   파장동   64   83   97  107  107  146  ...   22   28   16
# 24  경기도  수원시  팔달구   고등동  139  160  217  222  209  172  ...   13    8    8
# 22  경기도  수원시  팔달구   매교동   15   29   12   22   29   34  ...    7    2    2
# 23  경기도  수원시  팔달구   매산동   46   48   42   40   36   42  ...   15    6    8
# 28  경기도  수원시  팔달구  우만1동   51   70   69   90   59   98  ...   13    9    7
# 29  경기도  수원시  팔달구  우만2동   75   75   70   98  107  111  ...    9   12   11
# 30  경기도  수원시  팔달구   인계동  154  159  157  167  193  226  ...   22   21   12
# 27  경기도  수원시  팔달구    지동   16   22   33   31   36   43  ...   13   16    8
# 31  경기도  수원시  팔달구   행궁동   21   27   32   29   25   34  ...   17    9   10
# 25  경기도  수원시  팔달구  화서1동  107  100  108  111  127  157  ...   11   13   19
# 26  경기도  수원시  팔달구  화서2동  168  151  143  171  156  179  ...   17    9    9
#
#     94세  95세  96세  97세  98세  99세  100세 이상
# 20   14    4    3    0    2    5        3
# 15   13    3    4    3    0    2        3
# 18    5    6    3    3    0    0        2
# 19    4    6    8    5    1    3        8
# 16   21    5    4    4    2    1        4
# 14   10    8    9   10    2    1        5
# 10    4    5    1    4    1    2        1
# 11    7    6    7    9    5    5        6
# 12    9    7    4    0    1    0        3
# 21    6    3    2    3    0    0        2
# 13   14    9   13    6    4    2        9
# 17   11    7   10    1    0    2        3
# 42    7    4    4    2    5    2        3
# 43    9    2    9    5    1    1        4
# 40    6    4    5    2    0    0        4
# 41    4    1    1    2    0    0        3
# 32    5    0    6    3    2    1        1
# 33    5    8    4    1    1    0        2
# 34    6    3    7    0    1    1        3
# 35    7    1    5    5    3    0        2
# 37    6   10    1    4    1    2        3
# 38    1    0    0    3    0    2        3
# 39    7    3    3    3    3    3        1
# 36   14    9    1    2    2    0        2
# 6     3    7    3    3    0    0        5
# 9    18   13    6    4    6    2        4
# 5    11    6   11    3    4    2        3
# 1    18   10    7    5    3    4        5
# 2    17    5    4    3    5    1        4
# 3    17   11    5    5    5    6        6
# 4    11    7    1    3    4    0        2
# 7    19   12    7    6    1    4        2
# 8     5   13    6    2    3    6        4
# 0    10    3    4    4    3    6        2
# 24    2    5    4    1    4    1        2
# 22    3    0    1    0    2    0        2
# 23    7    4    2    2    0    1        3
# 28   10    5    6    5    3    1        4
# 29    6    4    1    2    1    2        0
# 30    8    8    7    4    4    2        5
# 27    4    3    3    0    1    1        2
# 31    7    9    0    4    1    0        1
# 25   10    1    7    1    0    4        4
# 26    7    4    5    2    2    3        4
#
# [44 rows x 105 columns]

# %% [markdown]
# ## [5] 데이터 회전
# ### 다음 조건을 순서대로 구현하여 ndf에 대입하고 인쇄하라
# 1. df에서 '동' 컬럼을 index화한다
# 2. '행궁동'과 '인계동' 2개 행과 나이 컬럼들('0세' ~ '100세이상')을 인덱싱한다
# 3. 행과 열을 회전하여 재구성한 결과를 ndf에 대입하고 인쇄하라(다음 그림 참조(일부))
# ![image-3.png](attachment:image-3.png)

# %%
# [5] 코드 작성
ndf = df.set_index('동').loc[['행궁동','인계동'],'0세':].T
ndf
# Out:
# 동        행궁동  인계동
# 0세        21  154
# 1세        27  159
# 2세        32  157
# 3세        29  167
# 4세        25  193
# ...      ...  ...
# 96세        0    7
# 97세        4    4
# 98세        1    4
# 99세        0    2
# 100세 이상    1    5
#
# [101 rows x 2 columns]

# %% [markdown]
# ## [6] line차트 시각화 예시
# ### 위 [5]번문제에서 완성한 ndf를 이용하여 행궁동과 인계동의 인구분포도를 시각화하는 다음 코드를 이해하라
# - plot() 옵션
#     - style : 점, 라인, 색상을 지정한다. 순서 무관하게 서로 조합하여 '--b'와 같은 문자열로 지정
#         - marker(점모양) : .(point), o(circle), v, ^, < , >, s, *, X, +등등
#         - line모양 : -, --, :, -.
#         - color : b, g, r, x, m , k(black), w
#     - xlabel, ylabel : 축 제목 지정

# %%
# [6] 코드 이해
ndf = df.set_index('동').loc[['행궁동','인계동'], '0세':].T

# line style, y축제목(ylabel), xtick 지정하여 꾸미기
ndf.plot(figsize=(15,5), style=['-.r', '--g'], ylabel='인구수', xticks=range(0,101,10))
# Out:
# <AxesSubplot: ylabel='인구수'>

# %% [markdown]
# ## [7]특정지역의 20대 연령층만 line차트 시각화
# ### 7-1. df에서 ['동']을 index화하고 주어진 3개지역(col변수)의 20대 연령만 추출하여 행과 열을 회전한 데이터프레임을 ndf변수에 대입하라
# - 다음 그림은 완성된 ndf이다
# ![image-6.png](attachment:image-6.png)

# %%
col = ['영통1동','영통2동','영통3동']

# [7-1] 코드 작성
ndf = df.set_index('동').loc[col,'20세':'29세'].T
ndf
# Out:
# 동    영통1동  영통2동  영통3동
# 20세   449   263   502
# 21세   499   306   646
# 22세   475   283   675
# 23세   438   365   716
# 24세   467   441   748
# 25세   445   551   747
# 26세   458   671   643
# 27세   496   685   662
# 28세   444   857   618
# 29세   536   890   573

# %% [markdown]
# ### 7-2. 주어진 style변수를 이용하여 ndf을 line 차트로 시각화하라
# 다음 그림은 영통 3개 지역의 20대 연령의 분포도를 line 차트로 시각화한 결과이다
# ![image-7.png](attachment:image-7.png)

# %%
style = ['^:r', 'o--m', 's-.g']

# [7-2] 코드 작성
ndf.plot(figsize=(15,5), style=style, xticks=range(0,10,1))
# Out:
# <AxesSubplot: >
